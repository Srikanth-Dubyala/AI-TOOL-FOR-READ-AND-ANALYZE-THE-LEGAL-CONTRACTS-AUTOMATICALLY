# %% [markdown]
# #### Importing Of Libaries

# %%
import json
from typing import Dict
from langchain_community.document_loaders import PyPDFLoader,TextLoader,UnstructuredWordDocumentLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import ChatHuggingFace,HuggingFaceEndpoint
from langchain_core.prompts import PromptTemplate
from langgraph.graph import StateGraph,END
from pinecone import Pinecone
from typing import Annotated,TypedDict,List
import operator
from langchain_core.utils.json import parse_json_markdown

# %% [markdown]
# #### hugging face api integretion in your aiproject environment

# %%
# conda activate your env_name 
# huggingface-cli login
#Enter your token (input will not be visible):"your api token" (if you you want paste :right click)
#Add token as git credential? (Y/n) n
#(aiproject) C:\Users\Admin>huggingface-cli whoami

# %% [markdown]
# #### Model

# %%
llm = HuggingFaceEndpoint(repo_id = "mistralai/Mistral-7B-Instruct-v0.2",
                              task ="text-generation and text-analysis"
                         )
chat_model = ChatHuggingFace(llm = llm)

# %% [markdown]
# #### Parsing ( To get Structured Output)

# %%
class AgentState(TypedDict):
    chunks: List
    finance: list
    legal: list
    operation: list
    compliance: list
    final: list

# %% [markdown]
# #### Loading the document and Splitting of data

# %%
# function to load based on there types
def doc_types_and_split(file_path):
    if file_path.endswith(".pdf"):
        loader = PyPDFLoader(file_path)
    elif file_path.endswith(".txt"):
        loader = TextLoader(file_path)
    elif filepath.endswith(".docx"):
        loader = UnstructuredWordDocumentLoader(filepath)
    else:
        raise ValueError("Unsupported file type .Supported:pdf,txt,docx")
    docs = loader.load()  # text of that page ,meta (like page number)
    # consolidate thr text from multiple document into one continous string
    splitter = RecursiveCharacterTextSplitter(chunk_size = 800,chunk_overlap = 100)
    return splitter.split_documents(docs)

# %% [markdown]
# #### Classifying of domain

# %%
def classifier(state: AgentState):
    for c in state["chunks"]:
        c.metadata["domains"] = ["finance", "legal", "operation", "compliance"]
    return {"chunks": state["chunks"]}

# %% [markdown]
# #### Prompt Templates

# %%
finance_prompt = PromptTemplate(
    input_variables=["clause"],
    template="""
Return JSON ONLY.

{{
  "risk_level": "LOW | MEDIUM | HIGH",
  "risk_type":['payment terms','fees','penalties', 'credit_risks', 'revenue_impact']
  "impact": "string",
  "recommendation": "string"
}}
Clause:
{clause}
"""
)

# %%
legal_prompt = PromptTemplate(
    input_variables=["clause"],
    template="""
Return JSON ONLY.

{{
  "risk_level": "LOW | MEDIUM | HIGH",
  "risk_type":['summary','key_obligations', 'legal_risks', 'termination_rules', 'liability_terms']
  "legal_issue": "string",
  "explanation": "string"
}}

Clause:
{clause}
"""
)

# %%
operation_prompt = PromptTemplate(
    input_variables=["clause"],
    template="""
Return JSON ONLY.

{{
  "risk_level": "LOW | MEDIUM | HIGH",
  "risk_type":['operational_dependencies', 'onboarding_requirements', 'security_concerns', 'SLA_items', 'action_items']
  "dependency": "string",
  "operational_impact": "string"
}}
Clause:
{clause}
"""
)

# %%
compliance_prompt = PromptTemplate(
    input_variables=["clause", "finance_findings"],
    template="""
Clause:
{clause}

Finance Findings:
{finance_findings}

Return JSON ONLY.

{{
  "risk_level": "LOW | MEDIUM | HIGH",
  "compliance_area": ['deliverables', 'notice_periods', 'renewal_terms', 'milestones', 'compliance_checklist']
  "violation": "string",
  "required_action": "string"
}}
"""
)

# %% [markdown]
# #### Embeddings

# %%
from langchain_huggingface.embeddings import HuggingFaceEmbeddings

embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# %% [markdown]
# #### Pine Cone intergration

# %%
## in anaconda prompt
# conda activate  your env_name
# setx PINECONE_API_KEY "your_api_key"
# setx PINECONE_ENVIORNMENT_NAME "your _env'

# %%
import os
from langchain_pinecone import PineconeVectorStore
from pinecone import Pinecone, ServerlessSpec
pc= Pinecone(api_key = os.environ.get("PINECONE_API_KEY"))
index_name = pc.Index("contract-analysis")
vectorstore = PineconeVectorStore(
    index=index_name,
    embedding=embedding_model
    )
print("vector initlaized successfully")
# Out:
# vector initlaized successfully

# %% [markdown]
# #### storing of embeddings

# %%
def store_to_pinecone(
    clause_id: str,
    domain: str,
    clause_text: str,
    structured_output: dict
):
    vectorstore.add_texts(
        texts=[clause_text],
        metadatas=[{
            "clause_id": clause_id,
            "domain": domain,
            "risk_level": structured_output.get("risk_level", "UNKNOWN"),
            "output": json.dumps(structured_output)
        }],
        ids=[f"{clause_id}_{domain}"]
    )

# %% [markdown]
# #### Finance agent

# %%
def finance_agent(state: AgentState):
    results = []
    for i, c in enumerate(state["chunks"]):
        res = chat_model.invoke(finance_prompt.format(clause=c.page_content)).content
        try:
            parsed = parse_json_markdown(res)
        except Exception as e:
            print(f"error parsing chunk {i} :{e}")
            continue
        store_to_pinecone(f"chunk_{i}", "finance", c.page_content, parsed)
        results.append({"clause_id": f"chunk_{i}", "output": parsed})
    return {"finance": results}

# %% [markdown]
# #### Legal_agent

# %%
def legal_agent(state: AgentState):
    results = []
    for i, c in enumerate(state["chunks"]):
        res = chat_model.invoke(legal_prompt.format(clause=c.page_content)).content
        try:
            parsed = parse_json_markdown(res)
        except Exception as e:
            print(f"error parsing chunk {i} :{e}")
            continue
        store_to_pinecone(f"chunk_{i}", "legal", c.page_content, parsed)
        results.append({"clause_id": f"chunk_{i}", "output": parsed})
    return {"legal": results}

# %% [markdown]
# #### Operation_agent

# %%
def operation_agent(state: AgentState):
    results = []
    for i, c in enumerate(state["chunks"]):
        res = chat_model.invoke(operation_prompt.format(clause=c.page_content)).content
        try:
            parsed = parse_json_markdown(res)
        except Exception as e:
            print(f"error parsing chunk {i} :{e}")
            continue
        store_to_pinecone(f"chunk_{i}", "operation", c.page_content, parsed)
        results.append({"clause_id": f"chunk_{i}", "output": parsed})
    return {"operation": results}

# %% [markdown]
# #### Compliance_agent

# %%
def compliance_agent(state: AgentState):
    results = []

    finance_map = {
        f["clause_id"]: f["output"]
        for f in state.get("finance", [])
    }

    for i, c in enumerate(state["chunks"]):
        finance_ctx = finance_map.get(f"chunk_{i}", {})
        res = chat_model.invoke(
            compliance_prompt.format(
                clause=c.page_content,
                finance_findings=json.dumps(finance_ctx)
            )
        ).content

        try:
            parsed = parse_json_markdown(res)
        except Exception as e:
            print(f"error parsing chunk {i} :{e}")
            continue
        store_to_pinecone(f"chunk_{i}", "compliance", c.page_content, parsed)
        results.append({"clause_id": f"chunk_{i}", "output": parsed})

    return {"compliance": results}

# %% [markdown]
# ##### resolver

# %%
def resolver(state: AgentState):
    final = []
    for key in ["finance","legal","operation","compliance"]:
        final.extend(state.get(key, []))
    state["final"] = final
    return state

# %% [markdown]
# #### Langgraph

# %%
graph = StateGraph(AgentState)
graph.add_node("classifier", classifier)
graph.add_node("finance", finance_agent)
graph.add_node("legal", legal_agent)
graph.add_node("operation", operation_agent)
graph.add_node("compliance", compliance_agent)
graph.add_node("resolver", resolver)
graph.set_entry_point("classifier")
graph.add_edge("classifier", "finance")
graph.add_edge("classifier", "legal")
graph.add_edge("classifier", "operation")
graph.add_edge("classifier", "compliance")
graph.add_edge("finance", "resolver")
graph.add_edge("legal", "resolver")
graph.add_edge("operation", "resolver")
graph.add_edge("compliance", "resolver")
graph.add_edge("resolver", END)
app = graph.compile()

# %%
if __name__ == "__main__":
    chunks = doc_types_and_split("Documents/Documents/contract/Contract document.pdf")
    output =app.invoke({"chunks": chunks})
    print(json.dumps(output["final"], indent=2))
# Out:
# [
#   {
#     "clause_id": "chunk_0",
#     "output": {
#       "risk_level": "MEDIUM",
#       "risk_type": [
#         "payment terms"
#       ],
#       "impact": "Late payments from client may cause cash flow issues for the contractor.",
#       "recommendation": "Consider including a clause that allows for interest on late payments or invoices due. Also, consider setting up a payment schedule or milestone payments to ensure consistent cash flow."
#     }
#   },
#   {
#     "clause_id": "chunk_1",
#     "output": {
#       "risk_level": "MEDIUM",
#       "risk_type": [
#         "payment terms",
#         "credit_risks"
#       ],
#       "impact": "Late payment by the client beyond the agreed 15-day term may impact Contractor's cash flow and financial stability.",
#       "recommendation": "Consider implementing a formal invoicing and payment process with clear communication regarding payment terms and potential consequences for late payments."
#     }
#   },
#   {
#     "clause_id": "chunk_2",
#     "output": {
#       "risk_level": "MEDIUM",
#       "risk_type": [
#         "credit_risks"
#       ],
#       "impact": "Breach of confidentiality or intellectual property rights could lead to legal action and potential reputational damage for the client.",
#       "recommendation": "Ensure that appropriate confidentiality and non-disclosure agreements are in place with the contractor. Regularly review the contractor's compliance with these agreements and consider including penalties for breach."
#     }
#   },
#   {
#     "clause_id": "chunk_3",
#     "output": {
#       "risk_level": "MEDIUM",
#       "risk_type": [
#         "credit_risks",
#         "revenue_impact"
#       ],
#       "impact": "Potential for significant financial losses due to indemnification claims and breaches of the Agreement.",
#       "recommendation": "Consider negotiating for a higher deductible or limiting indemnification coverage to direct damages only. Review the client's financial stability before entering into the Agreement."
#     }
#   },
#   {
#     "clause_id": "chunk_4",
#     "output": {
#       "risk_level": "LOW",
#       "risk_type": [
#         "credit_risks"
#       ],
#       "impact": "This clause states that this Agreement supersedes all prior agreements or representations between the parties. If the Client's primary business address is in a jurisdiction with laws that conflict with this Agreement, there is a risk that prior agreements may still be valid. This could potentially lead to disputes or legal action.",
#       "recommendation": "Ensure that both parties have a clear understanding of the jurisdiction's conflict of laws rules and the impact on this Agreement. Consider seeking legal advice to address any potential conflicts or inconsistencies."
#     }
#   },
#   {
#     "clause_id": "chunk_0",
#     "output": {
#       "risk_level": "MEDIUM",
#       "risk_type": [
#         "legal_risks"
#       ],
#       "legal_issue": "The Agreement does not clearly define the relationship between the Client and the Contractor. The use of the term 'Independent Contractor' does not automatically mean that the Contractor is an independent contractor and not an employee. This ambiguity could potentially lead to disputes and misclassification issues, resulting in legal risks and financial consequences.",
#       "explanation": "It is important for the Agreement to clearly establish the nature of the relationship between the parties, as misclassification of employees as independent contractors can lead to significant legal and financial consequences. The Agreement should include provisions that specifically and clearly define the relationship as that of an independent contractor, and also outline the specific responsibilities and obligations of each party. Additionally, the Agreement should include provisions regarding the Contractor's control over the means and methods of performing the services to ensure that the Contractor maintains the necessary level of independence."
#     }
#   },
#   {
#     "clause_id": "chunk_1",
#     "output": {
#       "risk_level": "MEDium",
#       "risk_type": [
#         "legal_risks"
#       ],
#       "legal_issue": "The clause regarding payment terms (Clause 1) may create a potential risk for disputes if not adhered to strictly, leading to possible breaches and subsequent legal action.",
#       "explanation": "The clause allows for payment to be made only within 15 days of receipt of an invoice, which may put pressure on the payment process and increase the likelihood of errors or misunderstandings leading to disputes. It would be important for both parties to maintain clear and open communication and adhere strictly to this term to minimize any potential risks."
#     }
#   },
#   {
#     "clause_id": "chunk_2",
#     "output": {
#       "risk_level": "MEDIUM",
#       "risk_type": [
#         "legal_risks"
#       ],
#       "legal_issue": "The confidentiality and intellectual property clauses in the contract have the potential to create legal risks if not properly implemented or followed.",
#       "explanation": "The confidentiality clause limits the Contractor's ability to disclose or use certain information, which if breached, could result in legal action against the Contractor. The intellectual property clause specifies ownership of work products created for the Client, which, if not properly documented, could lead to disputes over intellectual property rights."
#     }
#   },
#   {
#     "clause_id": "chunk_3",
#     "output": {
#       "risk_level": "MEDium",
#       "risk_type": [
#         "legal_risks"
#       ],
#       "legal_issue": "The indemnification clause (Clause 8) is one-sided, placing all liability on the Contractor. It would be prudent to consider mutual indemnification or limit the Contractor's liability to a reasonable extent.",
#       "explanation": "While the warranties clause (Clause 7) seems standard, the indemnification clause (Clause 8) is a significant risk. By accepting this clause without modification, the Contractor assumes all liability for damages or claims arising from their breach of the Agreement or negligence in performing the Services. This could potentially include unlimited damages, which can be a substantial financial risk. In contrast, the limitation of liability clause (Clause 9) is more balanced, protecting both parties from indirect, incidental, and consequential damages, except for breaches of confidentiality or indemnification obligations."
#     }
#   },
#   {
#     "clause_id": "chunk_4",
#     "output": {
#       "risk_level": "LOW",
#       "risk_type": [
#         "summary"
#       ],
#       "legal_issue": "There is a clause stating that the jurisdiction of the contract will be determined by the location of the Client's primary business address. This could potentially lead to disputes regarding which jurisdiction applies if there is ambiguity or disagreement over the location of the Client's primary business address.",
#       "explanation": "It is important for both parties to clarify and agree on the applicable jurisdiction at the outset of the contract to avoid potential disputes and uncertainty. This can be done by including a specific jurisdiction selection clause in the contract."
#     }
#   },
#   {
#     "clause_id": "chunk_0",
#     "output": {
#       "risk_level": "MEDIUM",
#       "risk_type": [
#         "operational_dependencies",
#         "SLA_items"
#       ],
#       "dependency": "Payment terms and Payment method as per Exhibit B",
#       "operational_impact": "Delayed payments or incorrect payment methods may impact the operational efficiency and cash flow of the contractor. It is crucial to have clear communication and agreement on payment terms and methods to mitigate this risk."
#     }
#   },
#   {
#     "clause_id": "chunk_1",
#     "output": {
#       "risk_level": "MEDIUM",
#       "risk_type": [
#         "SLA_items",
#         "security_concerns"
#       ],
#       "dependency": "payment_terms",
#       "operational_impact": "Contractor may face financial consequences if they fail to make payment within 15 days of receiving an invoice as stated in clause 1. Delays in payment could impact their cash flow and potentially affect their ability to fulfill obligations under this agreement. Additionally, termination of the agreement without proper notice could result in financial loss for the Contractor as stated in clause 3."
#     }
#   },
#   {
#     "clause_id": "chunk_2",
#     "output": {
#       "risk_level": "MEDIUM",
#       "risk_type": [
#         "security_concerns"
#       ],
#       "dependency": "Confidential Information and Intellectual Property",
#       "operational_impact": "Breach of confidentiality or intellectual property rights can lead to legal action, reputational damage, and compromise of client data."
#     }
#   },
#   {
#     "clause_id": "chunk_3",
#     "output": {
#       "risk_level": "MEDIUM",
#       "risk_type": [
#         "security_concerns",
#         "SLA_items"
#       ],
#       "dependency": "Compliance with industry standards and professional performance in provision of Services",
#       "operational_impact": "Breaches of professional standards or negligence in performing Services could result in reputational damage, financial losses, and potential legal action against the Client"
#     }
#   },
#   {
#     "clause_id": "chunk_4",
#     "output": {
#       "risk_level": "LOW",
#       "risk_type": [
#         "jurisdictional_compliance"
#       ],
#       "dependency": "Client's business address and jurisdiction",
#       "operational_impact": "Compliance with local laws and regulations may impact the operational capabilities and costs of the contract"
#     }
#   },
#   {
#     "clause_id": "chunk_0",
#     "output": {
#       "risk_level": "LOW",
#       "compliance_area": [
#         "deliverables",
#         "notice_periods",
#         "renewal_terms",
#         "milestones",
#         "compliance_checklist"
#       ],
#       "violation": "The Agreement does not specify any notice period for termination of the contract.",
#       "required_action": "Consider adding termination notice periods in the Agreement."
#     }
#   },
#   {
#     "clause_id": "chunk_1",
#     "output": {
#       "risk_level": "LOW",
#       "compliance_area": [
#         "notice_periods"
#       ],
#       "violation": "The notice period for termination is not clearly specified in the clause provided.",
#       "required_action": "Consider adding a notice period to the termination clause for clarity and to manage expectations for both parties."
#     }
#   },
#   {
#     "clause_id": "chunk_2",
#     "output": {
#       "risk_level": "LOW",
#       "compliance_area": [
#         "intellectual_property"
#       ],
#       "violation": "Contractor's intellectual property rights for pre-existing materials not created for Client are not explicitly addressed in the agreement.",
#       "required_action": "Consider adding a clause to the agreement that clarifies Contractor's rights to pre-existing materials not created for Client."
#     }
#   },
#   {
#     "clause_id": "chunk_3",
#     "output": {
#       "risk_level": "MEDIUM",
#       "compliance_area": [
#         "deliverables"
#       ],
#       "violation": "The warranty clause (Clause 7) only states that the Contractor will perform the Services in a professional and workmanlike manner, but it does not specify any particular industry standard or benchmark. It is recommended to include a specific industry standard or benchmark to ensure clarity and measurability.",
#       "required_action": "Revise Clause 7 to include a specific industry standard or benchmark."
#     }
#   },
#   {
#     "clause_id": "chunk_4",
#     "output": {
#       "risk_level": "LOW",
#       "compliance_area": [
#         "jurisdiction"
#       ],
#       "violation": "The clause specifies the jurisdiction where the Client's primary business address is located, but no jurisdiction is mentioned in the clause.",
#       "required_action": "Amend the clause to include the specific jurisdiction."
#     }
#   }
# ]
